# %% [markdown]
# Hey There🖐, I will walk you through out the notebook. This Kernal is dedicated for **beginners**.
# Here you are going to obtain the predictive model with **~86% accurancy**. So without further delay lets start.

# %% [markdown]
# ![download.png](data:image/png;base64,...)

# %% [markdown]
# # **INTRODUCTION**

# %% [markdown]
# * The sinking of the Titanic is one of the most famous ships in history. On April 15, 1912, the Titanic sank after colliding with an iceberg while cruising, **killing 1,502 of its 2,224 passengers and crew**. The exciting event shocked the international community and led to better ship safety management.
#
# * One of the reasons why these wrecks caused so many casualties was that there were **not enough lifeboats** for passengers and crew. While there is some chance of surviving the sinking, some groups, such as women, children, and the upper classes, are more likely to survive than others. Click [here](https://www.kaggle.com/competitions/titanic) to know more

# %% [markdown]
# # **PROBLEM STATEMENT**

# %% [markdown]
# * In this challenge, we have been asked to complete an analysis to see what kind of people will survive. We specifically asked to use ML algorithm to predict **which passengers will survive** the crash.

# %% [markdown]
# # **CONTENT**

# %% [markdown]
# 1. Reading and Exploring data
# > Importing train and test data into notebook and understand overview of data
# 2. Preparing Data
# > Outliers are trimmed out
# 3. Exploratory Data Analysis
# > Dig in deeper into the predictive nature of each attributes available in data set and
# > clean the data in such way that it could be used for modelling
# 4. Breifing Workdone
# > Summarizing what has been done for each attributes to get clear picture
# 5. Modelling
# > First, I splitted the train data intp 8:2 and fitted with models to check accurancy. the model with highest accuracy is selected for predicting survival in test data provided in competation
# 6. File Submission

# %%
#Libraries for computing
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
from scipy import stats
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# # **READING AND EXPLORING DATA**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#reading train and test data into notebook
train_data = pd.read_csv('/content/drive/MyDrive/Python/Datasets/TitanicData/train.csv')
test_data = pd.read_csv('/content/drive/MyDrive/Python/Datasets/TitanicData/test.csv')
full_data = pd.concat([train_data, test_data])

# %%
#Exploring data
train_data.head(3).style.background_gradient(cmap='Greys')
# Out:
# <style type="text/css">
# #T_86c0d_row0_col0, #T_86c0d_row0_col1, #T_86c0d_row0_col5, #T_86c0d_row0_col7, #T_86c0d_row0_col9, #T_86c0d_row1_col2, #T_86c0d_row1_col7, #T_86c0d_row2_col6, #T_86c0d_row2_col7 {
#   background-color: #ffffff;
#   color: #000000;
# }
# #T_86c0d_row0_col2, #T_86c0d_row0_col6, #T_86c0d_row1_col1, #T_86c0d_row1_col5, #T_86c0d_row1_col6, #T_86c0d_row1_col9, #T_86c0d_row2_col0, #T_86c0d_row2_col1, #T_86c0d_row2_col2 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_86c0d_row1_col0 {
#   background-color: #959595;
#   color: #f1f1f1;
# }
# #T_86c0d_row2_col5 {
#   background-color: #d9d9d9;
#   color: #000000;
# }
# #T_86c0d_row2_col9 {
#   background-color: #fefefe;
#   color: #000000;
# }
# </style>
# <table id="T_86c0d" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_86c0d_level0_col0" class="col_heading level0 col0" >PassengerId</th>
#       <th id="T_86c0d_level0_col1" class="col_heading level0 col1" >Survived</th>
#       <th id="T_86c0d_level0_col2" class="col_heading level0 col2" >Pclass</th>
#       <th id="T_86c0d_level0_col3" class="col_heading level0 col3" >Name</th>
#       <th id="T_86c0d_level0_col4" class="col_heading level0 col4" >Sex</th>
#       <th id="T_86c0d_level0_col5" class="col_heading level0 col5" >Age</th>
#       <th id="T_86c0d_level0_col6" class="col_heading level0 col6" >SibSp</th>
#       <th id="T_86c0d_level0_col7" class="col_heading level0 col7" >Parch</th>
#       <th id="T_86c0d_level0_col8" class="col_heading level0 col8" >Ticket</th>
#       <th id="T_86c0d_level0_col9" class="col_heading level0 col9" >Fare</th>
#       <th id="T_86c0d_level0_col10" class="col_heading level0 col10" >Cabin</th>
#       <th id="T_86c0d_level0_col11" class="col_heading level0 col11" >Embarked</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_86c0d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_86c0d_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_86c0d_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_86c0d_row0_col2" class="data row0 col2" >3</td>
#       <td id="T_86c0d_row0_col3" class="data row0 col3" >Braund, Mr. Owen Harris</td>
#       <td id="T_86c0d_row0_col4" class="data row0 col4" >male</td>
#       <td id="T_86c0d_row0_col5" class="data row0 col5" >22.000000</td>
#       <td id="T_86c0d_row0_col6" class="data row0 col6" >1</td>
#       <td id="T_86c0d_row0_col7" class="data row0 col7" >0</td>
#       <td id="T_86c0d_row0_col8" class="data row0 col8" >A/5 21171</td>
#       <td id="T_86c0d_row0_col9" class="data row0 col9" >7.250000</td>
#       <td id="T_86c0d_row0_col10" class="data row0 col10" >nan</td>
#       <td id="T_86c0d_row0_col11" class="data row0 col11" >S</td>
#     </tr>
#     <tr>
#       <th id="T_86c0d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_86c0d_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_86c0d_row1_col1" class="data row1 col1" >1</td>
#       <td id="T_86c0d_row1_col2" class="data row1 col2" >1</td>
#       <td id="T_86c0d_row1_col3" class="data row1 col3" >Cumings, Mrs. John Bradley (Florence Briggs Thayer)</td>
#       <td id="T_86c0d_row1_col4" class="data row1 col4" >female</td>
#       <td id="T_86c0d_row1_col5" class="data row1 col5" >38.000000</td>
#       <td id="T_86c0d_row1_col6" class="data row1 col6" >1</td>
#       <td id="T_86c0d_row1_col7" class="data row1 col7" >0</td>
#       <td id="T_86c0d_row1_col8" class="data row1 col8" >PC 17599</td>
#       <td id="T_86c0d_row1_col9" class="data row1 col9" >71.283300</td>
#       <td id="T_86c0d_row1_col10" class="data row1 col10" >C85</td>
#       <td id="T_86c0d_row1_col11" class="data row1 col11" >C</td>
#     </tr>
#     <tr>
#       <th id="T_86c0d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_86c0d_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_86c0d_row2_col1" class="data row2 col1" >1</td>
#       <td id="T_86c0d_row2_col2" class="data row2 col2" >3</td>
#       <td id="T_86c0d_row2_col3" class="data row2 col3" >Heikkinen, Miss. Laina</td>
#       <td id="T_86c0d_row2_col4" class="data row2 col4" >female</td>
#       <td id="T_86c0d_row2_col5" class="data row2 col5" >26.000000</td>
#       <td id="T_86c0d_row2_col6" class="data row2 col6" >0</td>
#       <td id="T_86c0d_row2_col7" class="data row2 col7" >0</td>
#       <td id="T_86c0d_row2_col8" class="data row2 col8" >STON/O2. 3101282</td>
#       <td id="T_86c0d_row2_col9" class="data row2 col9" >7.925000</td>
#       <td id="T_86c0d_row2_col10" class="data row2 col10" >nan</td>
#       <td id="T_86c0d_row2_col11" class="data row2 col11" >S</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **An overview of data types:**
# * Numerical Features: Age (Continuous), Fare (Continuous), SibSp (Discrete), Parch (Discrete), Survived(Discrete)
# * Categorical Features:  Sex, Embarked, Pclass
# * Alphanumeric Features: Ticket, Cabin

# %%
#Understanding statistics of dataframe
train_data.describe(include='all').style.background_gradient(cmap='Greys')
# Out:
# <style type="text/css">
# #T_dff08_row0_col0, #T_dff08_row0_col1, #T_dff08_row0_col2, #T_dff08_row0_col5, #T_dff08_row0_col6, #T_dff08_row0_col7, #T_dff08_row0_col9, #T_dff08_row1_col0, #T_dff08_row1_col1, #T_dff08_row1_col2, #T_dff08_row1_col5, #T_dff08_row1_col6, #T_dff08_row1_col7, #T_dff08_row1_col9, #T_dff08_row2_col0, #T_dff08_row2_col1, #T_dff08_row2_col2, #T_dff08_row2_col5, #T_dff08_row2_col6, #T_dff08_row2_col7, #T_dff08_row2_col9, #T_dff08_row3_col0, #T_dff08_row3_col1, #T_dff08_row3_col2, #T_dff08_row3_col5, #T_dff08_row3_col6, #T_dff08_row3_col7, #T_dff08_row3_col9, #T_dff08_row10_col0 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_dff08_row4_col0, #T_dff08_row8_col0 {
#   background-color: #959595;
#   color: #f1f1f1;
# }
# #T_dff08_row4_col1, #T_dff08_row4_col2, #T_dff08_row4_col6, #T_dff08_row4_col7, #T_dff08_row5_col1, #T_dff08_row5_col2, #T_dff08_row5_col6, #T_dff08_row5_col7, #T_dff08_row6_col0, #T_dff08_row6_col1, #T_dff08_row6_col2, #T_dff08_row6_col5, #T_dff08_row6_col6, #T_dff08_row6_col7, #T_dff08_row6_col9, #T_dff08_row7_col1, #T_dff08_row7_col2, #T_dff08_row7_col6, #T_dff08_row7_col7, #T_dff08_row8_col1, #T_dff08_row8_col2, #T_dff08_row8_col6, #T_dff08_row8_col7, #T_dff08_row9_col1, #T_dff08_row9_col2, #T_dff08_row9_col6, #T_dff08_row9_col7, #T_dff08_row10_col1, #T_dff08_row10_col2, #T_dff08_row10_col7 {
#   background-color: #ffffff;
#   color: #000000;
# }
# #T_dff08_row4_col5 {
#   background-color: #fafafa;
#   color: #000000;
# }
# #T_dff08_row4_col9, #T_dff08_row8_col5, #T_dff08_row9_col9 {
#   background-color: #fbfbfb;
#   color: #000000;
# }
# #T_dff08_row5_col0 {
#   background-color: #d1d1d1;
#   color: #000000;
# }
# #T_dff08_row5_col5, #T_dff08_row8_col9 {
#   background-color: #fdfdfd;
#   color: #000000;
# }
# #T_dff08_row5_col9 {
#   background-color: #f8f8f8;
#   color: #000000;
# }
# #T_dff08_row7_col0 {
#   background-color: #d9d9d9;
#   color: #000000;
# }
# #T_dff08_row7_col5 {
#   background-color: #fcfcfc;
#   color: #000000;
# }
# #T_dff08_row7_col9, #T_dff08_row10_col6 {
#   background-color: #fefefe;
#   color: #000000;
# }
# #T_dff08_row9_col0 {
#   background-color: #515151;
#   color: #f1f1f1;
# }
# #T_dff08_row9_col5 {
#   background-color: #f9f9f9;
#   color: #000000;
# }
# #T_dff08_row10_col5 {
#   background-color: #f2f2f2;
#   color: #000000;
# }
# #T_dff08_row10_col9 {
#   background-color: #818181;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_dff08" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dff08_level0_col0" class="col_heading level0 col0" >PassengerId</th>
#       <th id="T_dff08_level0_col1" class="col_heading level0 col1" >Survived</th>
#       <th id="T_dff08_level0_col2" class="col_heading level0 col2" >Pclass</th>
#       <th id="T_dff08_level0_col3" class="col_heading level0 col3" >Name</th>
#       <th id="T_dff08_level0_col4" class="col_heading level0 col4" >Sex</th>
#       <th id="T_dff08_level0_col5" class="col_heading level0 col5" >Age</th>
#       <th id="T_dff08_level0_col6" class="col_heading level0 col6" >SibSp</th>
#       <th id="T_dff08_level0_col7" class="col_heading level0 col7" >Parch</th>
#       <th id="T_dff08_level0_col8" class="col_heading level0 col8" >Ticket</th>
#       <th id="T_dff08_level0_col9" class="col_heading level0 col9" >Fare</th>
#       <th id="T_dff08_level0_col10" class="col_heading level0 col10" >Cabin</th>
#       <th id="T_dff08_level0_col11" class="col_heading level0 col11" >Embarked</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dff08_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_dff08_row0_col0" class="data row0 col0" >891.000000</td>
#       <td id="T_dff08_row0_col1" class="data row0 col1" >891.000000</td>
#       <td id="T_dff08_row0_col2" class="data row0 col2" >891.000000</td>
#       <td id="T_dff08_row0_col3" class="data row0 col3" >891</td>
#       <td id="T_dff08_row0_col4" class="data row0 col4" >891</td>
#       <td id="T_dff08_row0_col5" class="data row0 col5" >714.000000</td>
#       <td id="T_dff08_row0_col6" class="data row0 col6" >891.000000</td>
#       <td id="T_dff08_row0_col7" class="data row0 col7" >891.000000</td>
#       <td id="T_dff08_row0_col8" class="data row0 col8" >891</td>
#       <td id="T_dff08_row0_col9" class="data row0 col9" >891.000000</td>
#       <td id="T_dff08_row0_col10" class="data row0 col10" >204</td>
#       <td id="T_dff08_row0_col11" class="data row0 col11" >889</td>
#     </tr>
#     <tr>
#       <th id="T_dff08_level0_row1" class="row_heading level0 row1" >unique</th>
#       <td id="T_dff08_row1_col0" class="data row1 col0" >nan</td>
#       <td id="T_dff08_row1_col1" class="data row1 col1" >nan</td>
#       <td id="T_dff08_row1_col2" class="data row1 col2" >nan</td>
#       <td id="T_dff08_row1_col3" class="data row1 col3" >891</td>
#       <td id="T_dff08_row1_col4" class="data row1 col4" >2</td>
#       <td id="T_dff08_row1_col5" class="data row1 col5" >nan</td>
#       <td id="T_dff08_row1_col6" class="data row1 col6" >nan</td>
#       <td id="T_dff08_row1_col7" class="data row1 col7" >nan</td>
#       <td id="T_dff08_row1_col8" class="data row1 col8" >681</td>
#       <td id="T_dff08_row1_col9" class="data row1 col9" >nan</td>
#       <td id="T_dff08_row1_col10" class="data row1 col10" >147</td>
#       <td id="T_dff08_row1_col11" class="data row1 col11" >3</td>
#     </tr>
#     <tr>
#       <th id="T_dff08_level0_row2" class="row_heading level0 row2" >top</th>
#       <td id="T_dff08_row2_col0" class="data row2 col0" >nan</td>
#       <td id="T_dff08_row2_col1" class="data row2 col1" >nan</td>
#       <td id="T_dff08_row2_col2" class="data row2 col2" >nan</td>
#       <td id="T_dff08_row2_col3" class="data row2 col3" >Braund, Mr. Owen Harris</td>
#       <td id="T_dff08_row2_col4" class="data row2 col4" >male</td>
#       <td id="T_dff08_row2_col5" class="data row2 col5" >nan</td>
#       <td id="T_dff08_row2_col6" class="data row2 col6" >nan</td>
#       <td id="T_dff08_row2_col7" class="data row2 col7" >nan</td>
#       <td id="T_dff08_row2_col8" class="data row2 col8" >347082</td>
#       <td id="T_dff08_row2_col9" class="data row2 col9" >nan</td>
#       <td id="T_dff08_row2_col10" class="data row2 col10" >B96 B98</td>
#       <td id="T_dff08_row2_col11" class="data row2 col11" >S</td>
#     </tr>
#     <tr>
#       <th id="T_dff08_level0_row3" class="row_heading level0 row3" >freq</th>
#       <td id="T_dff08_row3_col0" class="data row3 col0" >nan</td>
#       <td id="T_dff08_row3_col1" class="data row3 col1" >nan</td>
#       <td id="T_dff08_row3_col2" class="data row3 col2" >nan</td>
#       <td id="T_dff08_row3_col3" class="data row3 col3" >1</td>
#       <td id="T_dff08_row3_col4" class="data row3 col4" >577</td>
#       <td id="T_dff08_row3_col5" class="data row3 col5" >nan</td>
#       <td id="T_dff08_row3_col6" class="data row3 col6" >nan</td>
#       <td id="T_dff08_row3_col7" class="data row3 col7" >nan</td>
#       <td id="T_dff08_row3_col8" class="data row3 col8" >7</td>
#       <td id="T_dff08_row3_col9" class="data row3 col9" >nan</td>
#       <td id="T_dff08_row3_col10" class="data row3 col10" >4</td>
#       <td id="T_dff08_row3_col11" class="data row3 col11" >644</td>
#     </tr>
#     <tr>
#       <th id="T_dff08_level0_row4" class="row_heading level0 row4" >mean</th>
#       <td id="T_dff08_row4_col0" class="data row4 col0" >446.000000</td>
#       <td id="T_dff08_row4_col1" class="data row4 col1" >0.383838</td>
#       <td id="T_dff08_row4_col2" class="data row4 col2" >2.308642</td>
#       <td id="T_dff08_row4_col3" class="data row4 col3" >nan</td>
#       <td id="T_dff08_row4_col4" class="data row4 col4" >nan</td>
#       <td id="T_dff08_row4_col5" class="data row4 col5" >29.699118</td>
#       <td id="T_dff08_row4_col6" class="data row4 col6" >0.523008</td>
#       <td id="T_dff08_row4_col7" class="data row4 col7" >0.381594</td>
#       <td id="T_dff08_row4_col8" class="data row4 col8" >nan</td>
#       <td id="T_dff08_row4_col9" class="data row4 col9" >32.204208</td>
#       <td id="T_dff08_row4_col10" class="data row4 col10" >nan</td>
#       <td id="T_dff08_row4_col11" class="data row4 col11" >nan</td>
#     </tr>
#     <t

# %% [markdown]
# **Info:**
# * From PassengerId : There are a total of 891 passengers in our training set. Moreover this column doesnt share any correlation to target attribute.
#
# * From Survived & SibSp & Parch & Fare: could possibly have outliers as std is greater than its mean value

# %%
#Exploring train data frame
pd.set_option('display.max_columns', None)
def data_overview(df, head=5):
    print(" SHAPE ".center(125,'-'))
    print('Rows:{}'.format(df.shape[0]))
    print('Columns:{}'.format(df.shape[1]))
    print(" HEAD ".center(125,'-'))
    print(df.head(head))
    print(" MISSING VALUES ".center(125,'-'))
    print(df.isnull().sum())
    print(" DUPLICATED VALUES ".center(125,'-'))
    print(df.duplicated().sum())
    print(" DATA TYPES ".center(125,'-'))
    print(df.dtypes)

data_overview(train_data)
# Out:
# ----------------------------------------------------------- SHAPE -----------------------------------------------------------
# Rows:891
# Columns:12
# ------------------------------------------------------------ HEAD -----------------------------------------------------------
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# ------------------------------------------------------- MISSING VALUES ------------------------------------------------------
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64
# ----------------------------------------------------- DUPLICATED VALUES -----------------------------------------------------
# 0
# --------------------------------------------------------- DATA TYPES --------------------------------------------------------
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# **Info:**
# * There are missing values in Age, Cabin and Embarked columns.

# %%
#Exploring test data frame
pd.set_option('display.max_columns', None)
def data_overview(df, head=5):
    print(" SHAPE ".center(125,'-'))
    print('Rows:{}'.format(df.shape[0]))
    print('Columns:{}'.format(df.shape[1]))
    print(" HEAD ".center(125,'-'))
    print(df.head(head))
    print(" MISSING VALUES ".center(125,'-'))
    print(df.isnull().sum())
    print(" DUPLICATED VALUES ".center(125,'-'))
    print(df.duplicated().sum())
    print(" DATA TYPES ".center(125,'-'))
    print(df.dtypes)

data_overview(test_data)
# Out:
# ----------------------------------------------------------- SHAPE -----------------------------------------------------------
# Rows:418
# Columns:11
# ------------------------------------------------------------ HEAD -----------------------------------------------------------
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S
# ------------------------------------------------------- MISSING VALUES ------------------------------------------------------
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64
# ----------------------------------------------------- DUPLICATED VALUES -----------------------------------------------------
# 0
# --------------------------------------------------------- DATA TYPES --------------------------------------------------------
# PassengerId      int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# **Info:**
# * There are missing values in Age, Cabin, Fare columns.

# %% [markdown]
# # **PREPARING DATA (Outliers Removal)**

# %%
#Lets visialize the numerical continous features for outliers
sns.set(rc={"axes.facecolor":"#FFF9ED","figure.facecolor":"#FFF9ED"})
print("Reletive Plot Of Some Selected Features: A Data Subset")
plt.figure()
sns.pairplot(train_data[[ "Survived","Age","SibSp", "Parch","Fare"]], hue= "Survived",palette= "dark")
# Out:
# Reletive Plot Of Some Selected Features: A Data Subset

# %%
#Dropping the outliers by setting a cap on SibSp and Fare.
print("The total number of data-points before removing the outliers are:", len(train_data))
train_data = train_data[(train_data["SibSp"]<6)]
train_data = train_data[(train_data["Fare"]<350)]
train_data = train_data[(train_data["Parch"]<5)]
print("The total number of data-points after removing the outliers are:", len(train_data))
# Out:
# The total number of data-points before removing the outliers are: 891
# The total number of data-points after removing the outliers are: 875

# %% [markdown]
# # **EXPLORATORY DATA ANALYSIS**

# %% [markdown]
# > * objective is to get clear idea of each variables and establish selection criteria for modelling.

# %% [markdown]
# ### 1. Pclass

# %%
print(" Number of passengers by their boarding class ".center(50,'-'))
print(train_data["Pclass"].value_counts())
# Out:
# -- Number of passengers by their boarding class --
# 3    478
# 1    213
# 2    184
# Name: Pclass, dtype: int64

# %%
cols = ['grey','black','silver']
plt.figure(figsize=(5,3))
sns.barplot(x = train_data["Pclass"], y = train_data["Survived"],palette=cols)
plt.title("Survival rate by class")
plt.show()

# %% [markdown]
# **Info:**
# * The survival rate increases with increase in boarding class. Noted that ~ 50% of passengers belongs to 3rd class.
# * Conclusion: Pclass to Include for building model alogrithm

# %% [markdown]
# ### 2. Name

# %%
# Extracting salutation to check the correlation with Target
train_data['Title'] = train_data['Name'].apply(lambda x: x.split(',')[1].split('.')[0].strip())

train_data['Title'].replace({'Mlle': 'Miss', 'Mme': 'Mrs', 'Ms': 'Miss'}, inplace = True)

train_data['Title'].replace(['Don', 'Rev', 'Dr', 'Major',  'Col', 'Capt', 'Jonkheer'],
                           'Rare Title', inplace = True)

train_data['Title'].replace(['the Countess', 'Lady', 'Sir'],'Honarary', inplace = True)

train_data['Title'].value_counts()
# Out:
# Mr            511
# Miss          181
# Mrs           121
# Master         39
# Rare Title     20
# Honarary        3
# Name: Title, dtype: int64

# %%
# repeating same for test data
test_data['Title'] = test_data['Name'].apply(lambda x: x.split(',')[1].split('.')[0].strip())
test_data['Title'].replace({'Mlle': 'Miss', 'Mme': 'Mrs', 'Ms': 'Miss'}, inplace = True)
test_data['Title'].replace(['Don', 'Rev', 'Dr', 'Major',  'Col', 'Capt', 'Jonkheer'],
                           'Rare Title', inplace = True)
test_data['Title'].replace(['the Countess', 'Lady', 'Sir','Dona'],'Honarary', inplace = True)
test_data['Title'].value_counts()
# Out:
# Mr            240
# Miss           79
# Mrs            72
# Master         21
# Rare Title      5
# Honarary        1
# Name: Title, dtype: int64

# %%
plt.figure(figsize=(7,5))
sns.barplot(x = train_data["Title"], y = train_data["Survived"],palette="dark")
plt.title("Survival rate by Title")
plt.show()

# %% [markdown]
# **Info:**
# * The survival rate is high for women ( Mrs and Ms) and common men (Mr) are least survived and to be noted that there were only 3 Honarary and all were rescued according to the record.
# * Conclusion: Title to include for building model alogrithm

# %%
#to include for modelling lets map each of the title groups to a numerical value (Encoding)
title_mapping = {"Mr": 1, "Miss": 2, "Mrs": 3, "Master": 4, "Rare Title": 5, "Honarary": 6}
train_data['Title'] = train_data['Title'].map(title_mapping)
test_data['Title'] = test_data['Title'].map(title_mapping)

# %%
#Dropping Name from both train and test
train_data = train_data.drop("Name",axis=1)
test_data = test_data.drop("Name",axis=1)
train_data.head(3).style.set_properties(subset=['Title'], **{'background-color': 'yellow'})
# Out:
# <style type="text/css">
# #T_dfcf2_row0_col11, #T_dfcf2_row1_col11, #T_dfcf2_row2_col11 {
#   background-color: yellow;
# }
# </style>
# <table id="T_dfcf2" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dfcf2_level0_col0" class="col_heading level0 col0" >PassengerId</th>
#       <th id="T_dfcf2_level0_col1" class="col_heading level0 col1" >Survived</th>
#       <th id="T_dfcf2_level0_col2" class="col_heading level0 col2" >Pclass</th>
#       <th id="T_dfcf2_level0_col3" class="col_heading level0 col3" >Sex</th>
#       <th id="T_dfcf2_level0_col4" class="col_heading level0 col4" >Age</th>
#       <th id="T_dfcf2_level0_col5" class="col_heading level0 col5" >SibSp</th>
#       <th id="T_dfcf2_level0_col6" class="col_heading level0 col6" >Parch</th>
#       <th id="T_dfcf2_level0_col7" class="col_heading level0 col7" >Ticket</th>
#       <th id="T_dfcf2_level0_col8" class="col_heading level0 col8" >Fare</th>
#       <th id="T_dfcf2_level0_col9" class="col_heading level0 col9" >Cabin</th>
#       <th id="T_dfcf2_level0_col10" class="col_heading level0 col10" >Embarked</th>
#       <th id="T_dfcf2_level0_col11" class="col_heading level0 col11" >Title</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dfcf2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_dfcf2_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_dfcf2_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_dfcf2_row0_col2" class="data row0 col2" >3</td>
#       <td id="T_dfcf2_row0_col3" class="data row0 col3" >male</td>
#       <td id="T_dfcf2_row0_col4" class="data row0 col4" >22.000000</td>
#       <td id="T_dfcf2_row0_col5" class="data row0 col5" >1</td>
#       <td id="T_dfcf2_row0_col6" class="data row0 col6" >0</td>
#       <td id="T_dfcf2_row0_col7" class="data row0 col7" >A/5 21171</td>
#       <td id="T_dfcf2_row0_col8" class="data row0 col8" >7.250000</td>
#       <td id="T_dfcf2_row0_col9" class="data row0 col9" >nan</td>
#       <td id="T_dfcf2_row0_col10" class="data row0 col10" >S</td>
#       <td id="T_dfcf2_row0_col11" class="data row0 col11" >1</td>
#     </tr>
#     <tr>
#       <th id="T_dfcf2_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_dfcf2_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_dfcf2_row1_col1" class="data row1 col1" >1</td>
#       <td id="T_dfcf2_row1_col2" class="data row1 col2" >1</td>
#       <td id="T_dfcf2_row1_col3" class="data row1 col3" >female</td>
#       <td id="T_dfcf2_row1_col4" class="data row1 col4" >38.000000</td>
#       <td id="T_dfcf2_row1_col5" class="data row1 col5" >1</td>
#       <td id="T_dfcf2_row1_col6" class="data row1 col6" >0</td>
#       <td id="T_dfcf2_row1_col7" class="data row1 col7" >PC 17599</td>
#       <td id="T_dfcf2_row1_col8" class="data row1 col8" >71.283300</td>
#       <td id="T_dfcf2_row1_col9" class="data row1 col9" >C85</td>
#       <td id="T_dfcf2_row1_col10" class="data row1 col10" >C</td>
#       <td id="T_dfcf2_row1_col11" class="data row1 col11" >3</td>
#     </tr>
#     <tr>
#       <th id="T_dfcf2_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_dfcf2_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_dfcf2_row2_col1" class="data row2 col1" >1</td>
#       <td id="T_dfcf2_row2_col2" class="data row2 col2" >3</td>
#       <td id="T_dfcf2_row2_col3" class="data row2 col3" >female</td>
#       <td id="T_dfcf2_row2_col4" class="data row2 col4" >26.000000</td>
#       <td id="T_dfcf2_row2_col5" class="data row2 col5" >0</td>
#       <td id="T_dfcf2_row2_col6" class="data row2 col6" >0</td>
#       <td id="T_dfcf2_row2_col7" class="data row2 col7" >STON/O2. 3101282</td>
#       <td id="T_dfcf2_row2_col8" class="data row2 col8" >7.925000</td>
#       <td id="T_dfcf2_row2_col9" class="data row2 col9" >nan</td>
#       <td id="T_dfcf2_row2_col10" class="data row2 col10" >S</td>
#       <td id="T_dfcf2_row2_col11" class="data row2 col11" >2</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### 3. Sex

# %%
train_data["Sex"].value_counts()
# Out:
# male      570
# female    305
# Name: Sex, dtype: int64

# %%
cols = ['grey','black']
plt.figure(figsize=(5,3))
sns.barplot(x = train_data["Sex"], y = train_data["Survived"],palette=cols)
plt.title("Survival rate by Gender")
plt.show()

# %%
pd.crosstab(train_data['Sex'], train_data['Survived'], normalize = 'index')
# Out:
# Survived         0         1
# Sex
# female    0.242623  0.757377
# male      0.812281  0.187719

# %% [markdown]
# **Info:**
# * No doubt, Female has highest survival rate of ~75% compare to that of Men with ~ 20%.
# * Conclusion : Sex to include for building model alogrithm

# %%
#map each Sex value to a numerical value
sex_mapping = {"male": 0, "female": 1}
train_data['Sex'] = train_data['Sex'].map(sex_mapping)
test_data['Sex'] = test_data['Sex'].map(sex_mapping)

train_data.head(3).style.set_properties(subset=['Sex'], **{'background-color': 'yellow'})
# Out:
# <style type="text/css">
# #T_4f796_row0_col3, #T_4f796_row1_col3, #T_4f796_row2_col3 {
#   background-color: yellow;
# }
# </style>
# <table id="T_4f796" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4f796_level0_col0" class="col_heading level0 col0" >PassengerId</th>
#       <th id="T_4f796_level0_col1" class="col_heading level0 col1" >Survived</th>
#       <th id="T_4f796_level0_col2" class="col_heading level0 col2" >Pclass</th>
#       <th id="T_4f796_level0_col3" class="col_heading level0 col3" >Sex</th>
#       <th id="T_4f796_level0_col4" class="col_heading level0 col4" >Age</th>
#       <th id="T_4f796_level0_col5" class="col_heading level0 col5" >SibSp</th>
#       <th id="T_4f796_level0_col6" class="col_heading level0 col6" >Parch</th>
#       <th id="T_4f796_level0_col7" class="col_heading level0 col7" >Ticket</th>
#       <th id="T_4f796_level0_col8" class="col_heading level0 col8" >Fare</th>
#       <th id="T_4f796_level0_col9" class="col_heading level0 col9" >Cabin</th>
#       <th id="T_4f796_level0_col10" class="col_heading level0 col10" >Embarked</th>
#       <th id="T_4f796_level0_col11" class="col_heading level0 col11" >Title</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4f796_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4f796_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_4f796_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_4f796_row0_col2" class="data row0 col2" >3</td>
#       <td id="T_4f796_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_4f796_row0_col4" class="data row0 col4" >22.000000</td>
#       <td id="T_4f796_row0_col5" class="data row0 col5" >1</td>
#       <td id="T_4f796_row0_col6" class="data row0 col6" >0</td>
#       <td id="T_4f796_row0_col7" class="data row0 col7" >A/5 21171</td>
#       <td id="T_4f796_row0_col8" class="data row0 col8" >7.250000</td>
#       <td id="T_4f796_row0_col9" class="data row0 col9" >nan</td>
#       <td id="T_4f796_row0_col10" class="data row0 col10" >S</td>
#       <td id="T_4f796_row0_col11" class="data row0 col11" >1</td>
#     </tr>
#     <tr>
#       <th id="T_4f796_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4f796_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_4f796_row1_col1" class="data row1 col1" >1</td>
#       <td id="T_4f796_row1_col2" class="data row1 col2" >1</td>
#       <td id="T_4f796_row1_col3" class="data row1 col3" >1</td>
#       <td id="T_4f796_row1_col4" class="data row1 col4" >38.000000</td>
#       <td id="T_4f796_row1_col5" class="data row1 col5" >1</td>
#       <td id="T_4f796_row1_col6" class="data row1 col6" >0</td>
#       <td id="T_4f796_row1_col7" class="data row1 col7" >PC 17599</td>
#       <td id="T_4f796_row1_col8" class="data row1 col8" >71.283300</td>
#       <td id="T_4f796_row1_col9" class="data row1 col9" >C85</td>
#       <td id="T_4f796_row1_col10" class="data row1 col10" >C</td>
#       <td id="T_4f796_row1_col11" class="data row1 col11" >3</td>
#     </tr>
#     <tr>
#       <th id="T_4f796_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_4f796_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_4f796_row2_col1" class="data row2 col1" >1</td>
#       <td id="T_4f796_row2_col2" class="data row2 col2" >3</td>
#       <td id="T_4f796_row2_col3" class="data row2 col3" >1</td>
#       <td id="T_4f796_row2_col4" class="data row2 col4" >26.000000</td>
#       <td id="T_4f796_row2_col5" class="data row2 col5" >0</td>
#       <td id="T_4f796_row2_col6" class="data row2 col6" >0</td>
#       <td id="T_4f796_row2_col7" class="data row2 col7" >STON/O2. 3101282</td>
#       <td id="T_4f796_row2_col8" class="data row2 col8" >7.925000</td>
#       <td id="T_4f796_row2_col9" class="data row2 col9" >nan</td>
#       <td id="T_4f796_row2_col10" class="data row2 col10" >S</td>
#       <td id="T_4f796_row2_col11" class="data row2 col11" >2</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### 4. Age

# %%
plt.figure(figsize=(5,3))
sns.histplot(train_data["Age"],color="grey")
plt.title("Survival rate by Age")
plt.show()

# %% [markdown]
# #### Decision table for naming groups for Age:
#
# ![download (1).png](data:image/png;base64,...)

# %%
#replacing missing values with its Median
train_data["Age"].replace(np.nan,train_data["Age"].median(), inplace=True)
test_data["Age"].replace(np.nan,test_data["Age"].median(), inplace=True)

#Bin names
bin_names=["Baby","Child","Teenager","Early Adult","Adult","Late Adult","Senior"]

#Sorting asc and drawing divider to the column
bins_train = np.linspace(min(train_data["Age"]),max(train_data["Age"]),8)
bins_test = np.linspace(min(test_data["Age"]),max(test_data["Age"]),8)

#dividing the column
train_data["Age_binned"] = pd.cut(train_data["Age"],bins_train,labels = bin_names,include_lowest=True)
test_data["Age_binned"] = pd.cut(test_data["Age"],bins_test,labels = bin_names,include_lowest=True)

# %%
plt.figure(figsize=(7,5))
plt.title("Survival rate by Age group")
sns.barplot(x=train_data["Age_binned"],y=train_data["Survived"],palette="dark")
plt.show()

# %% [markdown]
# **Info:**
# * Babies with age group 1 to 5 is most likely to Survive
# * Conclusion :  Conclusion: Age to Include for building model alogrithm

# %%
# Converting to numerical data
title_mapping = {"Baby":1,"Child":2,"Teenager":3,"Early Adult":4,"Adult":5,"Late Adult":6,"Senior": 7}
train_data["Age_binned"] = train_data["Age_binned"].map(title_mapping)
test_data["Age_binned"] = test_data["Age_binned"].map(title_mapping)
train_data = train_data.drop("Age",axis=1)
test_data = test_data.drop("Age",axis=1)

# %% [markdown]
# ### 5. SibSp

# %%
train_data["SibSp"].value_counts()
# Out:
# 0    603
# 1    205
# 2     28
# 4     18
# 3     16
# 5      5
# Name: SibSp, dtype: int64

# %%
plt.figure(figsize=(7,5))
plt.title("Survival rate by SibSp")
sns.barplot(x=train_data["SibSp"],y=train_data["Survived"],palette='dark')
plt.show()

# %% [markdown]
# **Info:**
# * Here it is clear that people with 1 or 2 siblings or spouses are most likely to surivive.
# * In contradictory to previous, the person with higher than 2 siblings or spouses is less likely to survive and it applies same for the one who has no spouses or siblings.
# * Conclusion: SibSp to Include for building model alogrithm

# %% [markdown]
# ### 6. Parch

# %%
train_data["Parch"].value_counts()
# Out:
# 0    676
# 1    117
# 2     73
# 3      5
# 4      4
# Name: Parch, dtype: int64

# %%
plt.figure(figsize=(7,5))
plt.title("Survival rate by Parch")
sns.barplot(x=train_data["Parch"],y=train_data["Survived"],palette='dark')
plt.show()

# %% [markdown]
# **Info:**
# * People with 1-3 parents or Childern have relatively higher survival rate otherwise its low.
# * Conclusion: ParCh to Include for building model alogrithm

# %% [markdown]
# ### 7. Ticket and Cabin

# %%
# Considering to drop these two columns as Tikect dont contribute any information to predictive model and Cabin has ~80% missing values.
to_drop = ["Ticket","Cabin"]
train_data = train_data.drop(to_drop,axis=1)
test_data = test_data.drop(to_drop,axis=1)

# %% [markdown]
# **Info:**
# * Considering to drop these two columns as Tikect dont contribute any information to predictive model and Cabin has ~80% missing
# * Conclusion: Ticket and Cabin Variables to exculded for Modelling

# %% [markdown]
# ### 8. Fare

# %%
plt.figure(figsize=(5,3))
plt.title("Survival rate by Fare")
plt.xlim(0,200)
sns.histplot(train_data["Fare"],color="grey")
plt.show()

# %%
#Replacig missing value with median in test data
test_data["Fare"].replace(np.nan,test_data["Fare"].median(), inplace=True)

# %%
labels = ["low","mid","standard","premium","gold"]
train_data['Fare_binned'] = pd.qcut(train_data['Fare'],5,labels=labels)
test_data['Fare_binned'] = pd.qcut(test_data['Fare'], 5,labels=labels)
train_data['Fare_binned'].value_counts()
# Out:
# mid         184
# low         179
# gold        173
# premium     172
# standard    167
# Name: Fare_binned, dtype: int64

# %%
plt.figure(figsize=(7,5))
plt.title("Survival rate by Fare_binned")
sns.barplot(x=train_data["Fare_binned"],y=train_data["Survived"],palette='dark')
plt.show()

# %% [markdown]
# **Info:**
# * After binning Fare it is abvious that higher the fare price is higher will be the survival chance.
# * Conclusion: Fare_binned to include for Modelling

# %%
# Converting to numerical data
fare_mapping = {"low":1,"mid":2,"standard":3,"premium":4,"gold":5}
train_data["Fare_binned"] = train_data["Fare_binned"].map(fare_mapping)
test_data["Fare_binned"] = test_data["Fare_binned"].map(fare_mapping)
train_data = train_data.drop("Fare",axis=1)
test_data = test_data.drop("Fare",axis=1)

# %% [markdown]
# ### 8. Embarked

# %%
train_data["Embarked"].value_counts()
# Out:
# S    632
# C    165
# Q     76
# Name: Embarked, dtype: int64

# %%
#Replacing missing values from train data with frequency to embarked column
train_data["Embarked"].replace(np.nan, train_data["Embarked"].mode()[0], inplace=True)

# %%
plt.figure(figsize=(7,5))
plt.title("Survival rate by Embarked")
sns.countplot(x="Embarked",hue ="Survived", data =train_data,palette='dark')
plt.show()

# %% [markdown]
# **Info:**
# * People who boarded the ship from Cherbourg has higher survival rate when comapre to survival rate of other points.
# * Conclusion: Embarked Variables to include for Modelling

# %%
Embarked_mapping = {"S": 1, "C": 2, "Q": 3}
train_data['Embarked'] = train_data['Embarked'].map(Embarked_mapping)
test_data['Embarked'] = test_data['Embarked'].map(Embarked_mapping)

# %% [markdown]
# ### Finally this is how data looks

# %%
cm = sns.light_palette("green", as_cmap=True)
train_data.head().style.background_gradient(cmap=cm).set_precision(2)
# Out:
# <style type="text/css">
# #T_7742c_row0_col0, #T_7742c_row0_col1, #T_7742c_row0_col3, #T_7742c_row0_col5, #T_7742c_row0_col6, #T_7742c_row0_col7, #T_7742c_row1_col2, #T_7742c_row1_col5, #T_7742c_row2_col4, #T_7742c_row2_col5, #T_7742c_row2_col6, #T_7742c_row3_col2, #T_7742c_row3_col5, #T_7742c_row3_col6, #T_7742c_row4_col1, #T_7742c_row4_col3, #T_7742c_row4_col4, #T_7742c_row4_col5, #T_7742c_row4_col6, #T_7742c_row4_col7 {
#   background-color: #ebf3eb;
#   color: #000000;
# }
# #T_7742c_row0_col2, #T_7742c_row0_col4, #T_7742c_row1_col1, #T_7742c_row1_col3, #T_7742c_row1_col4, #T_7742c_row1_col6, #T_7742c_row1_col7, #T_7742c_row2_col1, #T_7742c_row2_col2, #T_7742c_row2_col3, #T_7742c_row3_col1, #T_7742c_row3_col3, #T_7742c_row3_col4, #T_7742c_row3_col7, #T_7742c_row4_col0, #T_7742c_row4_col2 {
#   background-color: #008000;
#   color: #f1f1f1;
# }
# #T_7742c_row1_col0 {
#   background-color: #b0d6b0;
#   color: #000000;
# }
# #T_7742c_row2_col0, #T_7742c_row2_col7 {
#   background-color: #75b975;
#   color: #f1f1f1;
# }
# #T_7742c_row3_col0 {
#   background-color: #3a9c3a;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_7742c" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7742c_level0_col0" class="col_heading level0 col0" >PassengerId</th>
#       <th id="T_7742c_level0_col1" class="col_heading level0 col1" >Survived</th>
#       <th id="T_7742c_level0_col2" class="col_heading level0 col2" >Pclass</th>
#       <th id="T_7742c_level0_col3" class="col_heading level0 col3" >Sex</th>
#       <th id="T_7742c_level0_col4" class="col_heading level0 col4" >SibSp</th>
#       <th id="T_7742c_level0_col5" class="col_heading level0 col5" >Parch</th>
#       <th id="T_7742c_level0_col6" class="col_heading level0 col6" >Embarked</th>
#       <th id="T_7742c_level0_col7" class="col_heading level0 col7" >Title</th>
#       <th id="T_7742c_level0_col8" class="col_heading level0 col8" >Age_binned</th>
#       <th id="T_7742c_level0_col9" class="col_heading level0 col9" >Fare_binned</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7742c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7742c_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_7742c_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_7742c_row0_col2" class="data row0 col2" >3</td>
#       <td id="T_7742c_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_7742c_row0_col4" class="data row0 col4" >1</td>
#       <td id="T_7742c_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_7742c_row0_col6" class="data row0 col6" >1</td>
#       <td id="T_7742c_row0_col7" class="data row0 col7" >1</td>
#       <td id="T_7742c_row0_col8" class="data row0 col8" >2</td>
#       <td id="T_7742c_row0_col9" class="data row0 col9" >1</td>
#     </tr>
#     <tr>
#       <th id="T_7742c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7742c_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_7742c_row1_col1" class="data row1 col1" >1</td>
#       <td id="T_7742c_row1_col2" class="data row1 col2" >1</td>
#       <td id="T_7742c_row1_col3" class="data row1 col3" >1</td>
#       <td id="T_7742c_row1_col4" class="data row1 col4" >1</td>
#       <td id="T_7742c_row1_col5" class="data row1 col5" >0</td>
#       <td id="T_7742c_row1_col6" class="data row1 col6" >2</td>
#       <td id="T_7742c_row1_col7" class="data row1 col7" >3</td>
#       <td id="T_7742c_row1_col8" class="data row1 col8" >4</td>
#       <td id="T_7742c_row1_col9" class="data row1 col9" >5</td>
#     </tr>
#     <tr>
#       <th id="T_7742c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7742c_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_7742c_row2_col1" class="data row2 col1" >1</td>
#       <td id="T_7742c_row2_col2" class="data row2 col2" >3</td>
#       <td id="T_7742c_row2_col3" class="data row2 col3" >1</td>
#       <td id="T_7742c_row2_col4" class="data row2 col4" >0</td>
#       <td id="T_7742c_row2_col5" class="data row2 col5" >0</td>
#       <td id="T_7742c_row2_col6" class="data row2 col6" >1</td>
#       <td id="T_7742c_row2_col7" class="data row2 col7" >2</td>
#       <td id="T_7742c_row2_col8" class="data row2 col8" >3</td>
#       <td id="T_7742c_row2_col9" class="data row2 col9" >2</td>
#     </tr>
#     <tr>
#       <th id="T_7742c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7742c_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_7742c_row3_col1" class="data row3 col1" >1</td>
#       <td id="T_7742c_row3_col2" class="data row3 col2" >1</td>
#       <td id="T_7742c_row3_col3" class="data row3 col3" >1</td>
#       <td id="T_7742c_row3_col4" class="data row3 col4" >1</td>
#       <td id="T_7742c_row3_col5" class="data row3 col5" >0</td>
#       <td id="T_7742c_row3_col6" class="data row3 col6" >1</td>
#       <td id="T_7742c_row3_col7" class="data row3 col7" >3</td>
#       <td id="T_7742c_row3_col8" class="data row3 col8" >4</td>
#       <td id="T_7742c_row3_col9" class="data row3 col9" >5</td>
#     </tr>
#     <tr>
#       <th id="T_7742c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_7742c_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_7742c_row4_col1" class="data row4 col1" >0</td>
#       <td id="T_7742c_row4_col2" class="data row4 col2" >3</td>
#       <td id="T_7742c_row4_col3" class="data row4 col3" >0</td>
#       <td id="T_7742c_row4_col4" class="data row4 col4" >0</td>
#       <td id="T_7742c_row4_col5" class="data row4 col5" >0</td>
#       <td id="T_7742c_row4_col6" class="data row4 col6" >1</td>
#       <td id="T_7742c_row4_col7" class="data row4 col7" >1</td>
#       <td id="T_7742c_row4_col8" class="data row4 col8" >4</td>
#       <td id="T_7742c_row4_col9" class="data row4 col9" >2</td>
#     </tr>
#   </tbody>
# </table>

# %%
cm = sns.light_palette("red", as_cmap=True)
test_data.head().style.background_gradient(cmap=cm).set_precision(2)
# Out:
# <style type="text/css">
# #T_80017_row0_col0, #T_80017_row0_col2, #T_80017_row0_col3, #T_80017_row0_col4, #T_80017_row0_col6, #T_80017_row1_col4, #T_80017_row1_col5, #T_80017_row2_col1, #T_80017_row2_col2, #T_80017_row2_col3, #T_80017_row2_col4, #T_80017_row2_col6, #T_80017_row3_col2, #T_80017_row3_col3, #T_80017_row3_col4, #T_80017_row3_col5, #T_80017_row3_col6, #T_80017_row4_col5 {
#   background-color: #f3f0f0;
#   color: #000000;
# }
# #T_80017_row0_col1, #T_80017_row0_col5, #T_80017_row1_col1, #T_80017_row1_col2, #T_80017_row1_col3, #T_80017_row1_col6, #T_80017_row2_col5, #T_80017_row3_col1, #T_80017_row4_col0, #T_80017_row4_col1, #T_80017_row4_col2, #T_80017_row4_col3, #T_80017_row4_col4, #T_80017_row4_col6 {
#   background-color: #ff0000;
#   color: #f1f1f1;
# }
# #T_80017_row1_col0 {
#   background-color: #f6b4b4;
#   color: #000000;
# }
# #T_80017_row2_col0 {
#   background-color: #f97878;
#   color: #f1f1f1;
# }
# #T_80017_row3_col0 {
#   background-color: #fc3b3b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_80017" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_80017_level0_col0" class="col_heading level0 col0" >PassengerId</th>
#       <th id="T_80017_level0_col1" class="col_heading level0 col1" >Pclass</th>
#       <th id="T_80017_level0_col2" class="col_heading level0 col2" >Sex</th>
#       <th id="T_80017_level0_col3" class="col_heading level0 col3" >SibSp</th>
#       <th id="T_80017_level0_col4" class="col_heading level0 col4" >Parch</th>
#       <th id="T_80017_level0_col5" class="col_heading level0 col5" >Embarked</th>
#       <th id="T_80017_level0_col6" class="col_heading level0 col6" >Title</th>
#       <th id="T_80017_level0_col7" class="col_heading level0 col7" >Age_binned</th>
#       <th id="T_80017_level0_col8" class="col_heading level0 col8" >Fare_binned</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_80017_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_80017_row0_col0" class="data row0 col0" >892</td>
#       <td id="T_80017_row0_col1" class="data row0 col1" >3</td>
#       <td id="T_80017_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_80017_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_80017_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_80017_row0_col5" class="data row0 col5" >3</td>
#       <td id="T_80017_row0_col6" class="data row0 col6" >1</td>
#       <td id="T_80017_row0_col7" class="data row0 col7" >4</td>
#       <td id="T_80017_row0_col8" class="data row0 col8" >2</td>
#     </tr>
#     <tr>
#       <th id="T_80017_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_80017_row1_col0" class="data row1 col0" >893</td>
#       <td id="T_80017_row1_col1" class="data row1 col1" >3</td>
#       <td id="T_80017_row1_col2" class="data row1 col2" >1</td>
#       <td id="T_80017_row1_col3" class="data row1 col3" >1</td>
#       <td id="T_80017_row1_col4" class="data row1 col4" >0</td>
#       <td id="T_80017_row1_col5" class="data row1 col5" >1</td>
#       <td id="T_80017_row1_col6" class="data row1 col6" >3</td>
#       <td id="T_80017_row1_col7" class="data row1 col7" >5</td>
#       <td id="T_80017_row1_col8" class="data row1 col8" >1</td>
#     </tr>
#     <tr>
#       <th id="T_80017_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_80017_row2_col0" class="data row2 col0" >894</td>
#       <td id="T_80017_row2_col1" class="data row2 col1" >2</td>
#       <td id="T_80017_row2_col2" class="data row2 col2" >0</td>
#       <td id="T_80017_row2_col3" class="data row2 col3" >0</td>
#       <td id="T_80017_row2_col4" class="data row2 col4" >0</td>
#       <td id="T_80017_row2_col5" class="data row2 col5" >3</td>
#       <td id="T_80017_row2_col6" class="data row2 col6" >1</td>
#       <td id="T_80017_row2_col7" class="data row2 col7" >6</td>
#       <td id="T_80017_row2_col8" class="data row2 col8" >2</td>
#     </tr>
#     <tr>
#       <th id="T_80017_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_80017_row3_col0" class="data row3 col0" >895</td>
#       <td id="T_80017_row3_col1" class="data row3 col1" >3</td>
#       <td id="T_80017_row3_col2" class="data row3 col2" >0</td>
#       <td id="T_80017_row3_col3" class="data row3 col3" >0</td>
#       <td id="T_80017_row3_col4" class="data row3 col4" >0</td>
#       <td id="T_80017_row3_col5" class="data row3 col5" >1</td>
#       <td id="T_80017_row3_col6" class="data row3 col6" >1</td>
#       <td id="T_80017_row3_col7" class="data row3 col7" >3</td>
#       <td id="T_80017_row3_col8" class="data row3 col8" >2</td>
#     </tr>
#     <tr>
#       <th id="T_80017_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_80017_row4_col0" class="data row4 col0" >896</td>
#       <td id="T_80017_row4_col1" class="data row4 col1" >3</td>
#       <td id="T_80017_row4_col2" class="data row4 col2" >1</td>
#       <td id="T_80017_row4_col3" class="data row4 col3" >1</td>
#       <td id="T_80017_row4_col4" class="data row4 col4" >1</td>
#       <td id="T_80017_row4_col5" class="data row4 col5" >1</td>
#       <td id="T_80017_row4_col6" class="data row4 col6" >3</td>
#       <td id="T_80017_row4_col7" class="data row4 col7" >3</td>
#       <td id="T_80017_row4_col8" class="data row4 col8" >3</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #  **BREIFING WORKDONE**

# %% [markdown]
# ![download (3).png](data:image/png;base64,...)

# %% [markdown]
# ### Splitting and Scaling data

# %%
X = train_data[train_data.columns[~train_data.columns.isin(['PassengerId','Survived'])]]
Y = train_data["Survived"] # Target Variable
scaler = StandardScaler()
X.head(3)
# Out:
#    Pclass  Sex  SibSp  Parch  Embarked  Title Age_binned Fare_binned
# 0       3    0      1      0         1      1          2           1
# 1       1    1      1      0         2      3          4           5
# 2       3    1      0      0         1      2          3           2

# %%
X_scaled = scaler.fit_transform(X)
X_scaled = pd.DataFrame(X_scaled) # Predictor
X_scaled.columns = ["Pclass","Sex","SibSp","Parch","Embarked","Title","Age_binned","Fare_binned"]
X_scaled.head(3).style.set_properties(**{'background-color': 'black',
                           'color': 'green'})
# Out:
# <style type="text/css">
# #T_a4a29_row0_col0, #T_a4a29_row0_col1, #T_a4a29_row0_col2, #T_a4a29_row0_col3, #T_a4a29_row0_col4, #T_a4a29_row0_col5, #T_a4a29_row0_col6, #T_a4a29_row0_col7, #T_a4a29_row1_col0, #T_a4a29_row1_col1, #T_a4a29_row1_col2, #T_a4a29_row1_col3, #T_a4a29_row1_col4, #T_a4a29_row1_col5, #T_a4a29_row1_col6, #T_a4a29_row1_col7, #T_a4a29_row2_col0, #T_a4a29_row2_col1, #T_a4a29_row2_col2, #T_a4a29_row2_col3, #T_a4a29_row2_col4, #T_a4a29_row2_col5, #T_a4a29_row2_col6, #T_a4a29_row2_col7 {
#   background-color: black;
#   color: green;
# }
# </style>
# <table id="T_a4a29" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a4a29_level0_col0" class="col_heading level0 col0" >Pclass</th>
#       <th id="T_a4a29_level0_col1" class="col_heading level0 col1" >Sex</th>
#       <th id="T_a4a29_level0_col2" class="col_heading level0 col2" >SibSp</th>
#       <th id="T_a4a29_level0_col3" class="col_heading level0 col3" >Parch</th>
#       <th id="T_a4a29_level0_col4" class="col_heading level0 col4" >Embarked</th>
#       <th id="T_a4a29_level0_col5" class="col_heading level0 col5" >Title</th>
#       <th id="T_a4a29_level0_col6" class="col_heading level0 col6" >Age_binned</th>
#       <th id="T_a4a29_level0_col7" class="col_heading level0 col7" >Fare_binned</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a4a29_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a4a29_row0_col0" class="data row0 col0" >0.834443</td>
#       <td id="T_a4a29_row0_col1" class="data row0 col1" >-0.731497</td>
#       <td id="T_a4a29_row0_col2" class="data row0 col2" >0.605520</td>
#       <td id="T_a4a29_row0_col3" class="data row0 col3" >-0.485428</td>
#       <td id="T_a4a29_row0_col4" class="data row0 col4" >-0.569454</td>
#       <td id="T_a4a29_row0_col5" class="data row0 col5" >-0.696416</td>
#       <td id="T_a4a29_row0_col6" class="data row0 col6" >-0.909513</td>
#       <td id="T_a4a29_row0_col7" class="data row0 col7" >-1.389532</td>
#     </tr>
#     <tr>
#       <th id="T_a4a29_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a4a29_row1_col0" class="data row1 col0" >-1.559451</td>
#       <td id="T_a4a29_row1_col1" class="data row1 col1" >1.367060</td>
#       <td id="T_a4a29_row1_col2" class="data row1 col2" >0.605520</td>
#       <td id="T_a4a29_row1_col3" class="data row1 col3" >-0.485428</td>
#       <td id="T_a4a29_row1_col4" class="data row1 col4" >1.002382</td>
#       <td id="T_a4a29_row1_col5" class="data row1 col5" >1.222841</td>
#       <td id="T_a4a29_row1_col6" class="data row1 col6" >0.805625</td>
#       <td id="T_a4a29_row1_col7" class="data row1 col7" >1.428175</td>
#     </tr>
#     <tr>
#       <th id="T_a4a29_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a4a29_row2_col0" class="data row2 col0" >0.834443</td>
#       <td id="T_a4a29_row2_col1" class="data row2 col1" >1.367060</td>
#       <td id="T_a4a29_row2_col2" class="data row2 col2" >-0.524181</td>
#       <td id="T_a4a29_row2_col3" class="data row2 col3" >-0.485428</td>
#       <td id="T_a4a29_row2_col4" class="data row2 col4" >-0.569454</td>
#       <td id="T_a4a29_row2_col5" class="data row2 col5" >0.263212</td>
#       <td id="T_a4a29_row2_col6" class="data row2 col6" >-0.051944</td>
#       <td id="T_a4a29_row2_col7" class="data row2 col7" >-0.685105</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # **MODELLING**

# %%
# To check Accurancy of different model, spliting Train_data into 80 % train and 20 % test is required.
x_train, x_test, y_train, y_test = train_test_split(X_scaled,Y,test_size=0.2,random_state=1)

# %% [markdown]
# I will be testing the following models with my training data (got the list from [here](https://www.kaggle.com/code/nadintamer/titanic-survival-predictions-beginner)):
#
# 1. Gaussian Naive Bayes
# 2. Logistic Regression
# 3. Support Vector Machines
# 4. Perceptron
# 5. Decision Tree Classifier
# 6. Random Forest Classifier
# 7. KNN or k-Nearest Neighbors
# 8. Stochastic Gradient Descent
# 9. Gradient Boosting Classifie

# %%
# Gaussian Naive Bayes
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score

gaussian = GaussianNB()
gaussian.fit(x_train, y_train)
ypred_gaussian = gaussian.predict(x_test)
acc_gaussian = round(accuracy_score(ypred_gaussian, y_test) * 100, 2)
print(acc_gaussian)
# Out:
# 83.43

# %%
# Logistic Regression
from sklearn.linear_model import LogisticRegression

logReg = LogisticRegression()
logReg.fit(x_train, y_train)
ypred_logReg = logReg.predict(x_test)
acc_logReg = round(accuracy_score(ypred_logReg, y_test) * 100, 2)
print(acc_logReg)
# Out:
# 81.71

# %%
# Support Vector Machines
from sklearn.svm import SVC

svc = SVC()
svc.fit(x_train, y_train)
ypred_svc = svc.predict(x_test)
acc_svc = round(accuracy_score(ypred_svc, y_test) * 100, 2)
print(acc_svc)
# Out:
# 85.71

# %%
# Perceptron
from sklearn.linear_model import Perceptron

perceptron = Perceptron()
perceptron.fit(x_train, y_train)
ypred_perceptron = perceptron.predict(x_test)
acc_perceptron = round(accuracy_score(ypred_perceptron, y_test) * 100, 2)
print(acc_perceptron)
# Out:
# 73.14

# %%
#Decision Tree
from sklearn.tree import DecisionTreeClassifier

decisiontree = DecisionTreeClassifier()
decisiontree.fit(x_train, y_train)
ypred_decisiontree = decisiontree.predict(x_test)
acc_decisiontree = round(accuracy_score(ypred_decisiontree, y_test) * 100, 2)
print(acc_decisiontree)
# Out:
# 82.86

# %%
# Random Forest
from sklearn.ensemble import RandomForestClassifier

randomforest = RandomForestClassifier()
randomforest.fit(x_train, y_train)
ypred_randomforest = randomforest.predict(x_test)
acc_randomforest = round(accuracy_score(ypred_randomforest, y_test) * 100, 2)
print(acc_randomforest)
# Out:
# 84.57

# %%
#KNN
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier()
knn.fit(x_train, y_train)
ypred_knn = knn.predict(x_test)
acc_knn = round(accuracy_score(ypred_knn, y_test) * 100, 2)
print(acc_knn)
# Out:
# 85.14

# %%
# Stochastic Gradient Descent
from sklearn.linear_model import SGDClassifier

sgd = SGDClassifier()
sgd.fit(x_train, y_train)
ypred_sgd = sgd.predict(x_test)
acc_sgd = round(accuracy_score(ypred_sgd, y_test) * 100, 2)
print(acc_sgd)
# Out:
# 77.71

# %%
# Gradient Boosting Classifier
from sklearn.ensemble import GradientBoostingClassifier

gbk = GradientBoostingClassifier()
gbk.fit(x_train, y_train)
ypred_gbk = gbk.predict(x_test)
acc_gbk = round(accuracy_score(ypred_gbk, y_test) * 100, 2)
print(acc_gbk)
# Out:
# 82.86

# %%
models = pd.DataFrame({
    'Model': ['Support Vector Machines', 'KNN', 'Logistic Regression',
              'Random Forest', 'Naive Bayes', 'Perceptron',
              'Decision Tree', 'Stochastic Gradient Descent', 'Gradient Boosting Classifier'],
    'Score': [acc_svc, acc_knn, acc_logReg,
              acc_randomforest, acc_gaussian, acc_perceptron, acc_decisiontree,
              acc_sgd, acc_gbk]})
models.sort_values(by='Score', ascending=False).style.highlight_max(axis=0)
# Out:
# <style type="text/css">
# #T_26baa_row0_col0, #T_26baa_row0_col1 {
#   background-color: yellow;
# }
# </style>
# <table id="T_26baa" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_26baa_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_26baa_level0_col1" class="col_heading level0 col1" >Score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_26baa_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_26baa_row0_col0" class="data row0 col0" >Support Vector Machines</td>
#       <td id="T_26baa_row0_col1" class="data row0 col1" >85.710000</td>
#     </tr>
#     <tr>
#       <th id="T_26baa_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_26baa_row1_col0" class="data row1 col0" >KNN</td>
#       <td id="T_26baa_row1_col1" class="data row1 col1" >85.140000</td>
#     </tr>
#     <tr>
#       <th id="T_26baa_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_26baa_row2_col0" class="data row2 col0" >Random Forest</td>
#       <td id="T_26baa_row2_col1" class="data row2 col1" >84.570000</td>
#     </tr>
#     <tr>
#       <th id="T_26baa_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_26baa_row3_col0" class="data row3 col0" >Naive Bayes</td>
#       <td id="T_26baa_row3_col1" class="data row3 col1" >83.430000</td>
#     </tr>
#     <tr>
#       <th id="T_26baa_level0_row4" class="row_heading level0 row4" >6</th>
#       <td id="T_26baa_row4_col0" class="data row4 col0" >Decision Tree</td>
#       <td id="T_26baa_row4_col1" class="data row4 col1" >82.860000</td>
#     </tr>
#     <tr>
#       <th id="T_26baa_level0_row5" class="row_heading level0 row5" >8</th>
#       <td id="T_26baa_row5_col0" class="data row5 col0" >Gradient Boosting Classifier</td>
#       <td id="T_26baa_row5_col1" class="data row5 col1" >82.860000</td>
#     </tr>
#     <tr>
#       <th id="T_26baa_level0_row6" class="row_heading level0 row6" >2</th>
#       <td id="T_26baa_row6_col0" class="data row6 col0" >Logistic Regression</td>
#       <td id="T_26baa_row6_col1" class="data row6 col1" >81.710000</td>
#     </tr>
#     <tr>
#       <th id="T_26baa_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_26baa_row7_col0" class="data row7 col0" >Stochastic Gradient Descent</td>
#       <td id="T_26baa_row7_col1" class="data row7 col1" >77.710000</td>
#     </tr>
#     <tr>
#       <th id="T_26baa_level0_row8" class="row_heading level0 row8" >5</th>
#       <td id="T_26baa_row8_col0" class="data row8 col0" >Perceptron</td>
#       <td id="T_26baa_row8_col1" class="data row8 col1" >73.140000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # **PREDICTION & FILE SUBMISSION**

# %%
#scaling test data
test_id = test_data['PassengerId']
predictors = test_data[test_data.columns[~test_data.columns.isin(['PassengerId'])]]
scaler_test = StandardScaler()
predictors.head(3)
# Out:
#    Pclass  Sex  SibSp  Parch  Embarked  Title Age_binned Fare_binned
# 0       3    0      0      0         3      1          4           2
# 1       3    1      1      0         1      3          5           1
# 2       2    0      0      0         3      1          6           2

# %%
predictors_scaled = scaler_test.fit_transform(predictors)
predictors_scaled = pd.DataFrame(predictors_scaled) # Predictor
predictors_scaled.columns = ["Pclass","Sex","SibSp","Parch","Embarked","Title","Age_binned","Fare_binned"]
predictors_scaled.head(3).style.set_properties(**{'background-color': 'black',
                           'color': 'green'})
# Out:
# <style type="text/css">
# #T_68b95_row0_col0, #T_68b95_row0_col1, #T_68b95_row0_col2, #T_68b95_row0_col3, #T_68b95_row0_col4, #T_68b95_row0_col5, #T_68b95_row0_col6, #T_68b95_row0_col7, #T_68b95_row1_col0, #T_68b95_row1_col1, #T_68b95_row1_col2, #T_68b95_row1_col3, #T_68b95_row1_col4, #T_68b95_row1_col5, #T_68b95_row1_col6, #T_68b95_row1_col7, #T_68b95_row2_col0, #T_68b95_row2_col1, #T_68b95_row2_col2, #T_68b95_row2_col3, #T_68b95_row2_col4, #T_68b95_row2_col5, #T_68b95_row2_col6, #T_68b95_row2_col7 {
#   background-color: black;
#   color: green;
# }
# </style>
# <table id="T_68b95" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_68b95_level0_col0" class="col_heading level0 col0" >Pclass</th>
#       <th id="T_68b95_level0_col1" class="col_heading level0 col1" >Sex</th>
#       <th id="T_68b95_level0_col2" class="col_heading level0 col2" >SibSp</th>
#       <th id="T_68b95_level0_col3" class="col_heading level0 col3" >Parch</th>
#       <th id="T_68b95_level0_col4" class="col_heading level0 col4" >Embarked</th>
#       <th id="T_68b95_level0_col5" class="col_heading level0 col5" >Title</th>
#       <th id="T_68b95_level0_col6" class="col_heading level0 col6" >Age_binned</th>
#       <th id="T_68b95_level0_col7" class="col_heading level0 col7" >Fare_binned</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_68b95_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_68b95_row0_col0" class="data row0 col0" >0.873482</td>
#       <td id="T_68b95_row0_col1" class="data row0 col1" >-0.755929</td>
#       <td id="T_68b95_row0_col2" class="data row0 col2" >-0.499470</td>
#       <td id="T_68b95_row0_col3" class="data row0 col3" >-0.400248</td>
#       <td id="T_68b95_row0_col4" class="data row0 col4" >2.243165</td>
#       <td id="T_68b95_row0_col5" class="data row0 col5" >-0.733897</td>
#       <td id="T_68b95_row0_col6" class="data row0 col6" >0.652641</td>
#       <td id="T_68b95_row0_col7" class="data row0 col7" >-0.703316</td>
#     </tr>
#     <tr>
#       <th id="T_68b95_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_68b95_row1_col0" class="data row1 col0" >0.873482</td>
#       <td id="T_68b95_row1_col1" class="data row1 col1" >1.322876</td>
#       <td id="T_68b95_row1_col2" class="data row1 col2" >0.616992</td>
#       <td id="T_68b95_row1_col3" class="data row1 col3" >-0.400248</td>
#       <td id="T_68b95_row1_col4" class="data row1 col4" >-0.677841</td>
#       <td id="T_68b95_row1_col5" class="data row1 col5" >1.238893</td>
#       <td id="T_68b95_row1_col6" class="data row1 col6" >1.507826</td>
#       <td id="T_68b95_row1_col7" class="data row1 col7" >-1.408319</td>
#     </tr>
#     <tr>
#       <th id="T_68b95_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_68b95_row2_col0" class="data row2 col0" >-0.315819</td>
#       <td id="T_68b95_row2_col1" class="data row2 col1" >-0.755929</td>
#       <td id="T_68b95_row2_col2" class="data row2 col2" >-0.499470</td>
#       <td id="T_68b95_row2_col3" class="data row2 col3" >-0.400248</td>
#       <td id="T_68b95_row2_col4" class="data row2 col4" >2.243165</td>
#       <td id="T_68b95_row2_col5" class="data row2 col5" >-0.733897</td>
#       <td id="T_68b95_row2_col6" class="data row2 col6" >2.363011</td>
#       <td id="T_68b95_row2_col7" class="data row2 col7" >-0.703316</td>
#     </tr>
#   </tbody>
# </table>

# %%
#Using SVM for Prediction
predictions = svc.predict(predictors_scaled)
#set the output as a dataframe and convert to csv file named submission.csv
#output = pd.DataFrame({ 'PassengerId' : p_id, 'Survived': predictions })
#output.to_csv('submission.csv', index=False)
